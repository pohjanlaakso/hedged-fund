# %%
# https://github.com/jarvijaakko/Apartment_hunting/blob/master/Apartment_scraper.ipynb
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
# %matplotlib inline
import requests
from httpx import Client
# Out:
# /Users/tatu/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
driver = webdriver.Chrome()

# %%
# Loop to loop through all pages
# Scrape first the number of pages (in progress)
url_list=[]
for p in range(1,180): #45
    url_01 = "https://asunnot.oikotie.fi/myytavat-asunnot?pagination="
    url_02 = str(p)
    url_03 = "&locations=%5B%22helsinki%22%5D&roomCount%5B%5D=2&roomCount%5B%5D=3&cardType=100" # 2/3 bedroom apartments     
    url_list.append(url_01 + url_02 + url_03)

# %%
# Define lists that will house the scraped results
addresses=[]
infos_a = []
infos_b = []
prices = []
sizes = []
alls = []

# %%
a = 'https://asunnot.oikotie.fi/myytavat-asunnot?pagination=1&'
b = 'locations=%5B%5B64,6,%22Helsinki%22%5D%5D&'
c = 'cardType=100&'
d = 'roomCount%5B%5D=2&roomCount%5B%5D=3&'
e = 'habitationType%5B%5D=1&'
f = 'lotOwnershipType%5B%5D=1&'
g = 'price%5Bmax%5D=400000&'
h = 'size%5Bmin%5D=50'

# %%
for i in url_list[0:179]:
    url = i
    driver.get(url)
    time.sleep(3)
    content = driver.page_source
    soup = BeautifulSoup(content)
    
    for a in soup.findAll('div',href=False, attrs={'class':'ot-card-v2__info-container padded padded--v20-h20'}):
        address=a.find('div', attrs={'class':'card-v2-text-container__text card-v2-text-container__text--bold'})
        info_a = a.find('p', attrs={'class': 'card-v2-text-container__text card-v2-text-container__text--wide paragraph paragraph--caption ng-star-inserted'})
        info_b = a.find('p', attrs={'class':'card-v2-text-container__text paragraph paragraph--caption ng-star-inserted'})
        price = a.find('div', attrs={'class': 'card-v2-text-container__column'})
        size = a.find('div', attrs={'class': 'card-v2-text-container__group card-v2-text-container__group--boxed'})

        print(address)
        
        # https://stackoverflow.com/questions/51664292/python-attributeerror-nonetype-object-has-no-attribute-text
        def type_handler(item, list):
            if item is not None:
                list.append(item.text)
            else:
                list.append(None) 
        
        type_handler(address, addresses)
        type_handler(info_a, infos_a)
        type_handler(info_b, infos_b)
        type_handler(price, prices)
        type_handler(size, sizes)
        
        #addresses.append(address.text)
        #infos_a.append(info_a.text)
        #infos_b.append(info_b.text)
        #prices.append(price.text)
        #sizes.append(size.text)
# Out:
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Halsuantie 3 B 24, Kannelmäki, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Föglönkuja 11 D 62, Laajasalo, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Torivoudinpolku 1 A, Oulunkylä, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kalevankatu 44 A, Kamppi, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Johan Sederholmin tie 8 B, Herttoniemi, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Aarteenetsijänkuja 8 B, Vesala, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Poutuntie 7 A, Pohjois-Haaga, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Priki Venuksen kuja 5 A, Sompasaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Töölönkatu 52 A, Töölö, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kauppalantie 44 A, Etelä-Haaga, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Gustav Pauligin katu 8 A, Aurinkolahti, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Luuvaniementie 3, Niemenmäki, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Saunalahdentie 13, Munkkiniemi, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Mustankivenkatu 3, Vuosaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kotinummentie 4, Ylä-Malmi, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Trumpettitie 8 f, Kannelmäki, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Väinämöisenkatu 21 A, Etu-Töölö, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Näyttelijäntie 4 A, Pohjois-Haaga, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">
Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Berliininkatu 9 B, Arabianranta, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Tankomäenkatu 10 C, Mellunkylä, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Susitie 20 B, Herttoniemi, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Veräjä 8 E, Veräjälaakso, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Veräjä 8 E, Veräjälaakso, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Porintie 9, Munkkivuori, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Helsinginkatu 34, Kallio, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Alankotie 18 C, Puistola, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Punavuorenkatu 15 A, Punavuori, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Laurinniityntie 17a B, Lassila, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Jäkälätie 13 b, Tapaninkylä, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Verkkosaarenranta 14, Verkkosaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Heinäpellontie 26 B, Malmi/Tapaninkylä, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Solvikinkatu 11 A, Aurinkolahti, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Katajaharjuntie 12 B, Lauttasaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Katajaharjuntie 12 B, Lauttasaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Vattuniemenkatu 14, Lauttasaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kalevankatu 61 B, Kamppi, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Reiherintie 8 E, Laajasalo, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kauniinilmankuja 5 A, Aurinkolahti, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Ruusankatu 4, Taka-Töölö, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Teollisuuskatu 28 B, Vallila, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Hämeentie 26, Kallio, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Pyynikintie 5 E, Pihlajisto, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Harjannetie 9, Viikinmäki, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Perttulantie 4, Lauttasaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Capellan puistotie 3 C, Kalasatama, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Helsinginkatu 34 B, Kallio, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Porvoonkatu 21 E, Alppila, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Saanatunturintie 1 F, Mellunmäki, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Urheilukatu 54 A, Töölö, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kalevankatu 26 A, Kamppi, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kiskontie 12 A, Ruskeasuo, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Tähtitorninkatu 14 B, Ullanlinna, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Vironkatu 12 B, Kruununhaka, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Silkkitie 6 E, Vartiokylä, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kiviparintie 2, Myllypuro, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Vuosaarentie 11, Vuosaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Mäkitorpantie 11 A, Oulunkylä, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kaarenjalka 6 D, Kontula, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Birger Kaipiaisen katu 4, Toukola, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Hämeentie 26, Kallio, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Konalantie 39, Konala, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Reginankuja 4 C, Herttoniemenranta, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Joukolantie 11, Käpylä, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kivikonkaari 7, Kivikko, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Isonvillasaarentie 10 C, Vuosaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Koukkusaarentie 7 A, Vuosaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kalevankatu 49, Kamppi, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Laivastokatu 8-10 B, Katajanokka, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Leikkikuja 3 B, Kontula, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Porthaninkatu 7 A, Kallio, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kivisaarentie 2 A, Vuosaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Kulosaaren Puistotie 44 A, Kulosaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Mustankivenaukio 5 A, Vuosaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Juhana Herttuan tie 12 E, Koskela, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Purjeentekijänkuja 9, Lauttasaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Haakoninlahdenkatu 9 B, Kruunuvuorenranta, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Suvitie 1 A, Tapaninvainio, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Näyttelijäntie 3 C, Pohjois-Haaga, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Pohjavedenportti 2, Vuosaari, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Munkkiniemen Puistotie 4, Munkkiniemi, Helsinki</div>
# <div _ngcontent-ng-c3980868311="" class="card-v2-text-container__text card-v2-text-container__text--bold">Pursimiehenkatu 11, Punavuori, Helsinki</div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 3
#       1 for i in url_list[0:179]:
#       2     url = i
# ----> 3     driver.get(url)
#       4     time.sleep(3)
#       5     content = driver.page_source
#
# File ~/Library/Python/3.9/lib/python/site-packages/selenium/webdriver/remote/webdriver.py:363, in WebDriver.get(self, url)
#     361 def get(self, url: str) -> None:
#     362     """Loads a web page in the current browser session."""
# --> 363     self.execute(Command.GET, {"url": url})
#
# File ~/Library/Python/3.9/lib/python/site-packages/selenium/webdriver/remote/webdriver.py:352, in WebDriver.execute(self, driver_command, params)
#     349     elif "sessionId" not in params:
#     350         params["sessionId"] = self.session_id
# --> 352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
#     354     self.error_handler.check_response(response)
#
# File ~/Library/Python/3.9/lib/python/site-packages/selenium/webdriver/remote/remote_connection.py:302, in RemoteConnection.execute(self, command, params)
#     300 trimmed = self._trim_large_entries(params)
#     301 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 302 return self._request(command_info[0], url, body=data)
#
# File ~/Library/Python/3.9/lib/python/site-packages/selenium/webdriver/remote/remote_connection.py:322, in RemoteConnection._request(self, method, url, body)
#     319     body = None
#     321 if self.keep_alive:
# --> 322     response = self._conn.request(method, url, body=body, headers=headers)
#     323     statuscode = response.status
#     324 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/_request_methods.py:144, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     136     return self.request_encode_url(
#     137         method,
#     138         url,
#    (...)
#     141         **urlopen_kw,
#     142     )
#     143 else:
# --> 144     return self.request_encode_body(
#     145         method, url, fields=fields, headers=headers, **urlopen_kw
#     146     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/_request_methods.py:279, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     275     extra_kw["headers"].setdefault("Content-Type", content_type)
#     277 extra_kw.update(urlopen_kw)
# --> 279 return self.urlopen(method, url, **extra_kw)
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:1349, in HTTPConnection.getresponse(self)
#    1347 try:
#    1348     try:
# -> 1349         response.begin()
#    1350     except ConnectionError:
#    1351         self.close()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/http/client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame({'Address':addresses, 'info_a':infos_a, 'info_b':infos_b, 'price':prices, 'size':sizes})
df.to_csv('Apartments.csv', index=False, encoding='utf-8')
# Out:
#                                             Address  \
# 0          Torivoudinpolku 1 A, Oulunkylä, Helsinki
# 1                Kalevankatu 44 A, Kamppi, Helsinki
# 2  Johan Sederholmin tie 8 B, Herttoniemi, Helsinki
# 3          Aarteenetsijänkuja 8 B, Vesala, Helsinki
# 4            Poutuntie 7 A, Pohjois-Haaga, Helsinki
#
#                                info_a  \
# 0  \n\t\t\t\tKerrostalo, 1930\n\t\t\t
# 1  \n\t\t\t\tKerrostalo, 1948\n\t\t\t
# 2  \n\t\t\t\tKerrostalo, 1990\n\t\t\t
# 3  \n\t\t\t\tKerrostalo, 1988\n\t\t\t
# 4  \n\t\t\t\tKerrostalo, 1954\n\t\t\t
#
#                                               info_b              price  \
# 0  \n\t\t\t\t3 h, k, 2 x wc, khh, 2 x kh, s (Yj 2...  \n444 000 €\n\n\n
# 1  \n\t\t\t\t2h+avok+alkovi+kph (yhtiöjärjestykse...  \n358 000 €\n\n\n
# 2                          \n\t\t\t\t2h+kk+s\n\t\t\t  \n204 000 €\n\n\n
# 3  \n\t\t\t\tOh k, rt, 2mh, kph, s, las.parv\n\t\t\t  \n145 000 €\n\n\n
# 4  \n\t\t\t\t2h+avok+kph+parveke (yhtiöjärjestyks...  \n238 000 €\n\n\n
#
#                                      size
# 0    \n\n444 000 €\n\n\n\n\n97 m²\n\n\n\n
# 1    \n\n358 000 €\n\n\n\n\n48 m²\n\n\n\n
# 2  \n\n204 000 €\n\n\n\n\n47,5 m²\n\n\n\n
# 3  \n\n145 000 €\n\n\n\n\n68,5 m²\n\n\n\n
# 4  \n\n238 000 €\n\n\n\n\n46,6 m²\n\n\n\n

# %%
df = pd.read_csv('Apartments.csv')
df.head()
# Out:
#                                             Address  \
# 0          Torivoudinpolku 1 A, Oulunkylä, Helsinki
# 1                Kalevankatu 44 A, Kamppi, Helsinki
# 2  Johan Sederholmin tie 8 B, Herttoniemi, Helsinki
# 3          Aarteenetsijänkuja 8 B, Vesala, Helsinki
# 4            Poutuntie 7 A, Pohjois-Haaga, Helsinki
#
#                                info_a  \
# 0  \n\t\t\t\tKerrostalo, 1930\n\t\t\t
# 1  \n\t\t\t\tKerrostalo, 1948\n\t\t\t
# 2  \n\t\t\t\tKerrostalo, 1990\n\t\t\t
# 3  \n\t\t\t\tKerrostalo, 1988\n\t\t\t
# 4  \n\t\t\t\tKerrostalo, 1954\n\t\t\t
#
#                                               info_b              price  \
# 0  \n\t\t\t\t3 h, k, 2 x wc, khh, 2 x kh, s (Yj 2...  \n444 000 €\n\n\n
# 1  \n\t\t\t\t2h+avok+alkovi+kph (yhtiöjärjestykse...  \n358 000 €\n\n\n
# 2                          \n\t\t\t\t2h+kk+s\n\t\t\t  \n204 000 €\n\n\n
# 3  \n\t\t\t\tOh k, rt, 2mh, kph, s, las.parv\n\t\t\t  \n145 000 €\n\n\n
# 4  \n\t\t\t\t2h+avok+kph+parveke (yhtiöjärjestyks...  \n238 000 €\n\n\n
#
#                                      size
# 0    \n\n444 000 €\n\n\n\n\n97 m²\n\n\n\n
# 1    \n\n358 000 €\n\n\n\n\n48 m²\n\n\n\n
# 2  \n\n204 000 €\n\n\n\n\n47,5 m²\n\n\n\n
# 3  \n\n145 000 €\n\n\n\n\n68,5 m²\n\n\n\n
# 4  \n\n238 000 €\n\n\n\n\n46,6 m²\n\n\n\n

# %%
df['info_b'].str.split(',', expand=True)
# Out:
#                                                       0              1  \
# 0                                         \n\t\t\t\t3 h              k
# 1     \n\t\t\t\t2h+avok+alkovi+kph (yhtiöjärjestykse...           None
# 2                             \n\t\t\t\t2h+kk+s\n\t\t\t           None
# 3                                        \n\t\t\t\tOh k             rt
# 4     \n\t\t\t\t2h+avok+kph+parveke (yhtiöjärjestyks...           None
# ...                                                 ...            ...
# 2299                                       \n\t\t\t\t3h              k
# 2300       \n\t\t\t\t2h+k+kph+lasitettu parveke\n\t\t\t           None
# 2301  \n\t\t\t\t2h+avokeittiö+kph+vh+las.parveke\n\t...           None
# 2302       \n\t\t\t\t3h+k+kph+lasitettu parveke\n\t\t\t           None
# 2303                                       \n\t\t\t\t3h   avok (YJ: 3h
#
#             2             3        4                        5     6     7  \
# 0      2 x wc           khh   2 x kh   s (Yj 2-3 h+k)\n\t\t\t  None  None
# 1        None          None     None                     None  None  None
# 2        None          None     None                     None  None  None
# 3         2mh           kph        s         las.parv\n\t\t\t  None  None
# 4        None          None     None                     None  None  None
# ...       ...           ...      ...                      ...   ...   ...
# 2299      kph    wc\n\t\t\t     None                     None  None  None
# 2300     None          None     None                     None  None  None
# 2301     None          None     None                     None  None  None
# 2302     None          None     None                     None  None  None
# 2303    halli   kk)\n\t\t\t     None                     None  None  None
#
#          8     9
# 0     None  None
# 1     None  None
# 2     None  None
# 3     None  None
# 4     None  None
# ...    ...   ...
# 2299  None  None
# 2300  None  None
# 2301  None  None
# 2302  None  None
# 2303  None  None
#
# [2304 rows x 10 columns]

# %%
# remove escape characters from columns (ugly solution but works relatively well)
#https://stackoverflow.com/questions/8115261/how-to-remove-all-the-escape-sequences-from-a-list-of-strings
df['info_a'] = df['info_a'].replace('\n\t\t\t\t', '', regex=True). replace('\n\t\t\t', '', regex=True) # https://stackoverflow.com/questions/6116978/how-to-replace-multiple-substrings-of-a-string
df['info_b'] = df['info_b'].replace('\n\t\t\t\t', '', regex=True). replace('\n\t\t\t', '', regex=True)
df['price'] = df['price'].replace('\n', '', regex=True). replace('\n\n\n', '', regex=True)
df['size'] = df['size'].replace('\n\n', '', regex=True). replace('\n\n\n\n\n', '', regex=True).replace('\n\n\n\n', '', regex=True)
df['size'] = df['size'].replace('\n', '', regex=True) #for some reason one escape character remains and has to be deleted with an extra line of code

# some data handling
# https://stackoverflow.com/questions/14745022/how-to-split-a-dataframe-string-column-into-two-columns

df[['street', 'area', 'town', 'extra_I']] = df['Address'].str.split(',', expand=True)
df[['building_type', 'year_built']] = df['info_a'].str.split(',', expand=True)

# remove price information from size column 
# https://stackoverflow.com/questions/73974777/python-remove-text-if-same-of-another-column
df['size'] = [df.loc[i, 'size']. replace(df.loc[i, 'price'], '') for i in df.index]

# split info_b into multiple columns
df['info_b'] = df['info_b'].replace('+', ',') # some columns have '+' delimiters instead of commas
df[['room_num', 'kitchen_type', 'bathroom', 'balcony', 'extra_I', 'extra_II', 'extra_III', 'extra_IV', 'extra_V', 'extra_VI']] = df['info_b'].str.split(',', expand=True)

# remove useless information from number of rooms column
df['room_num']=df['room_num'].str[0]

# show data frame
df.head()
# Out:
#                                             Address            info_a  \
# 0          Torivoudinpolku 1 A, Oulunkylä, Helsinki  Kerrostalo, 1930
# 1                Kalevankatu 44 A, Kamppi, Helsinki  Kerrostalo, 1948
# 2  Johan Sederholmin tie 8 B, Herttoniemi, Helsinki  Kerrostalo, 1990
# 3          Aarteenetsijänkuja 8 B, Vesala, Helsinki  Kerrostalo, 1988
# 4            Poutuntie 7 A, Pohjois-Haaga, Helsinki  Kerrostalo, 1954
#
#                                               info_b      price     size  \
# 0        3 h, k, 2 x wc, khh, 2 x kh, s (Yj 2-3 h+k)  444 000 €    97 m²
# 1  2h+avok+alkovi+kph (yhtiöjärjestyksen mukaan 1...  358 000 €    48 m²
# 2                                            2h+kk+s  204 000 €  47,5 m²
# 3                    Oh k, rt, 2mh, kph, s, las.parv  145 000 €  68,5 m²
# 4  2h+avok+kph+parveke (yhtiöjärjestyksen mukaan ...  238 000 €  46,6 m²
#
#                       street            area       town  extra_I  \
# 0        Torivoudinpolku 1 A       Oulunkylä   Helsinki   2 x kh
# 1           Kalevankatu 44 A          Kamppi   Helsinki     None
# 2  Johan Sederholmin tie 8 B     Herttoniemi   Helsinki     None
# 3     Aarteenetsijänkuja 8 B          Vesala   Helsinki        s
# 4              Poutuntie 7 A   Pohjois-Haaga   Helsinki     None
#
#   building_type year_built room_num kitchen_type bathroom balcony  \
# 0    Kerrostalo       1930        3            k   2 x wc     khh
# 1    Kerrostalo       1948        2         None     None    None
# 2    Kerrostalo       1990        2         None     None    None
# 3    Kerrostalo       1988        O           rt      2mh     kph
# 4    Kerrostalo       1954        2         None     None    None
#
#           extra_II extra_III extra_IV extra_V extra_VI
# 0   s (Yj 2-3 h+k)      None     None    None     None
# 1             None      None     None    None     None
# 2             None      None     None    None     None
# 3         las.parv      None     None    None     None
# 4             None      None     None    None     None

# %%
# remove non numeric characters from price and size columns
# https://stackoverflow.com/questions/44117326/how-can-i-remove-all-non-numeric-characters-from-all-the-values-in-a-particular

# remove m2 character
df['size'] = df['size'].str[:2]

# https://stackoverflow.com/questions/31700691/convert-commas-decimal-separators-to-dots-within-a-dataframe
df['size'] = [x.replace(',', '.') for x in df['size']]
df['size'] = df['size'].astype(float)

# same for price
df['price'] = [x.replace('€', '') for x in df['price']]
df['price'] = df['price'].str[:7]
df['price'] = df['price'].replace('\xa0', '', regex=True)
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df['price'] = df['price'].astype(float)

df.head()
# Out:
#                                             Address            info_a  \
# 0          Torivoudinpolku 1 A, Oulunkylä, Helsinki  Kerrostalo, 1930
# 1                Kalevankatu 44 A, Kamppi, Helsinki  Kerrostalo, 1948
# 2  Johan Sederholmin tie 8 B, Herttoniemi, Helsinki  Kerrostalo, 1990
# 3          Aarteenetsijänkuja 8 B, Vesala, Helsinki  Kerrostalo, 1988
# 4            Poutuntie 7 A, Pohjois-Haaga, Helsinki  Kerrostalo, 1954
#
#                                               info_b     price  size  \
# 0        3 h, k, 2 x wc, khh, 2 x kh, s (Yj 2-3 h+k)  444000.0  97.0
# 1  2h+avok+alkovi+kph (yhtiöjärjestyksen mukaan 1...  358000.0  48.0
# 2                                            2h+kk+s  204000.0  47.0
# 3                    Oh k, rt, 2mh, kph, s, las.parv  145000.0  68.0
# 4  2h+avok+kph+parveke (yhtiöjärjestyksen mukaan ...  238000.0  46.0
#
#                       street            area       town  extra_I  \
# 0        Torivoudinpolku 1 A       Oulunkylä   Helsinki   2 x kh
# 1           Kalevankatu 44 A          Kamppi   Helsinki     None
# 2  Johan Sederholmin tie 8 B     Herttoniemi   Helsinki     None
# 3     Aarteenetsijänkuja 8 B          Vesala   Helsinki        s
# 4              Poutuntie 7 A   Pohjois-Haaga   Helsinki     None
#
#   building_type year_built room_num kitchen_type bathroom balcony  \
# 0    Kerrostalo       1930        3            k   2 x wc     khh
# 1    Kerrostalo       1948        2         None     None    None
# 2    Kerrostalo       1990        2         None     None    None
# 3    Kerrostalo       1988        O           rt      2mh     kph
# 4    Kerrostalo       1954        2         None     None    None
#
#           extra_II extra_III extra_IV extra_V extra_VI
# 0   s (Yj 2-3 h+k)      None     None    None     None
# 1             None      None     None    None     None
# 2             None      None     None    None     None
# 3         las.parv      None     None    None     None
# 4             None      None     None    None     None

# %%
sub_df = df[['price', 'size', 'area', 'year_built', 'room_num']]
sub_df = sub_df.dropna(subset=['price', 'size', 'year_built'])

sub_df.head()
# Out:
#       price  size            area year_built room_num
# 0  444000.0  97.0       Oulunkylä       1930        3
# 1  358000.0  48.0          Kamppi       1948        2
# 2  204000.0  47.0     Herttoniemi       1990        2
# 3  145000.0  68.0          Vesala       1988        O
# 4  238000.0  46.0   Pohjois-Haaga       1954        2

# %%
sub_df.insert(2, 'sq_price', df['price'].div(df['size'], axis=0), True)

# %%
# adding a column for plumbing renovation assuming it was done 50 years after building the apartment
sub_df['year_built'] = sub_df['year_built'].astype(float)
sub_df.insert(2, 'pipe_repair', df['year_built'], True)
sub_df['pipe_repair'] = sub_df['pipe_repair'].astype(int) + 50

# %%
# df.applymap(lambda x: 1 if x >=25 else 0)
#sub_df.insert(2, 'piperepair_plug', 
#              sub_df['pipe_repair'].applymap( lambda x: 0 if x >= 2024 else ((2023-x)/40)*1500 ),
#              True)

#sub_df['pipe_repair'].applymap( lambda x: 0 if x >= 2024 else ((2023-x)/40)*1500 )

sub_df.insert(2, 'piperepair_plug', sub_df['pipe_repair'], True)
sub_df['piperepair_plug'] = sub_df['piperepair_plug'].map(lambda x: 0 if x >= 2024 else ((2023-x)/40)*1500)
sub_df = sub_df.round(2)
sub_df.head()
# Out:
#       price  size  piperepair_plug  pipe_repair  sq_price            area  \
# 0  444000.0  97.0           1612.5         1980   4577.32       Oulunkylä
# 1  358000.0  48.0            937.5         1998   7458.33          Kamppi
# 2  204000.0  47.0              0.0         2040   4340.43     Herttoniemi
# 3  145000.0  68.0              0.0         2038   2132.35          Vesala
# 4  238000.0  46.0            712.5         2004   5173.91   Pohjois-Haaga
#
#    year_built room_num
# 0      1930.0        3
# 1      1948.0        2
# 2      1990.0        2
# 3      1988.0        O
# 4      1954.0        2

# %%
sub_df['sqprice_adjusted'] = sub_df['sq_price'] + sub_df['piperepair_plug']

# %%
# build a function that saves the data frame into a csv-file for further calculations done in R
sub_df.to_csv('apartments_final.csv', index=False, encoding='utf-8')
